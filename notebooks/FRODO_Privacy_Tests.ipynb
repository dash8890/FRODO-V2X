# %% [markdown]
# # FRODO standalone privacy tests
#
# This notebook runs the aggregate temporal mutual-information test and the same-product classifier two-sample test. It prints paper-ready tables and displays both figures inline. The experiment intentionally excludes mobility, communication, ranking, latency, and RAINBOW-DQN.

# %%
# %run ./frodo_privacy_tests.py
